# %%
import pandas as pd

# %%
df = pd.read_csv('/home/ubuntu/joel/Setup_Dataset/HIGGS.csv', header= None, index_col=False, nrows=1000000)

# %%
df
# Out:
#          0         1         2         3         4         5         6   \
# 0       1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202
# 1       1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531
# 2       1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875
# 3       0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066
# 4       1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466
# ...     ...       ...       ...       ...       ...       ...       ...
# 999995  1.0  0.514256  0.441154  0.641281  0.376795  0.840085  0.812464
# 999996  1.0  1.586689  0.798600 -1.038389  0.186234 -1.465364  1.328488
# 999997  0.0  1.833751  0.194740  1.489664  0.453500  0.077691  1.112570
# 999998  0.0  0.617107 -1.137650 -0.610591  0.847996 -1.121593  0.908286
# 999999  0.0  1.680206  0.841455  1.303231  0.469627  0.386419  0.935218
#
#               7         8         9   ...        19        20        21  \
# ...

# %%
df.to_csv('CL1M.csv', index=False, header=False)
